# %% [markdown]
# <a href="https://colab.research.google.com/github/pabondaniel/Diplomado_Ciencia_Datos/blob/main/Tarea_4_Parte_1_Daniel_Pab%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <span style="color:#E6512A"><center>Tarea 4</center></span>

# %% [markdown]
# ## <span style="color:#E6512A">Clase #1</span>

# %%
#Importación de Pandas
import pandas as pd

# %%
#Creación de la clase
class Clase1Tarea4:
  contador=-1
  def __init__(self):
    Clase1Tarea4.contador+=1
    tabla = pd.read_csv("/content/iris.csv")
    try:
      print("Valor número ",self.contador ,"\n",tabla.iloc[self.contador])
      try:
        print("\n\nValor número ",self.contador+1 ,"\n" ,"\n", tabla.iloc[self.contador+1])
      except:
        print("\n\nValor número ",self.contador+1 ,"\n" ,"\n", "Error: Ya no hay más datos :(")
    except:
      print("\n\nValor número ",self.contador+1 ,"\n" ,"\n", "Error: Ya no hay más datos :(")
    Clase1Tarea4.contador+=1

# %%
#Visualización de los datos para entenderlos y su tamaño
datos = pd.read_csv("/content/iris.csv")
datos
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
#Iteración 1
iteracion1=Clase1Tarea4()
# Out:
# Valor número  0
#  sepal.length       5.1
# sepal.width        3.5
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 0, dtype: object
#
#
# Valor número  1
#
#  sepal.length       4.9
# sepal.width        3.0
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 1, dtype: object

# %%
#Iteración 2
iteracion2=Clase1Tarea4()
# Out:
# Valor número  2
#  sepal.length       4.7
# sepal.width        3.2
# petal.length       1.3
# petal.width        0.2
# variety         Setosa
# Name: 2, dtype: object
#
#
# Valor número  3
#
#  sepal.length       4.6
# sepal.width        3.1
# petal.length       1.5
# petal.width        0.2
# variety         Setosa
# Name: 3, dtype: object

# %%
#Prueba de funcionamiento si se salen del rango
for x in range(74):
  iteracionx=Clase1Tarea4()
  print("\n" ,"\n")
# Out:
# Valor número  4
#  sepal.length       5.0
# sepal.width        3.6
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 4, dtype: object
#
#
# Valor número  5
#
#  sepal.length       5.4
# sepal.width        3.9
# petal.length       1.7
# petal.width        0.4
# variety         Setosa
# Name: 5, dtype: object
#
#
#
# Valor número  6
#  sepal.length       4.6
# sepal.width        3.4
# petal.length       1.4
# petal.width        0.3
# variety         Setosa
# Name: 6, dtype: object
#
#
# Valor número  7
#
#  sepal.length       5.0
# sepal.width        3.4
# petal.length       1.5
# petal.width        0.2
# variety         Setosa
# Name: 7, dtype: object
#
#
#
# Valor número  8
#  sepal.length       4.4
# sepal.width        2.9
# petal.length       1.4
# petal.width        0.2
# variety         Setosa
# Name: 8, dtype: object
#
#
# Valor número  9
#
#  sepal.length       4.9
# sepal.width        3.1
# petal.length       1.5
# petal.width        0.1
# ...
